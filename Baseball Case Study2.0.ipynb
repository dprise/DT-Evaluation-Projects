# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# # Overview:-
#
# Major League Baseball, a professional baseball league in the US and Canada,
# is one of the most popular sports leagues in North America.
# Partially because of its popularity and the wide availability of
# data from games, baseball has become the subject of significant statistical and mathematical analysis. Machine learning techniques are more mathematically complex and able to fit variations in baseball game outcomes better.
#
# There is indeed a relationship between the statistics to a game and its outcome & baseball statistics can be collected and analyzed in such a way that provides accurate answers to specific questions. On the basis of predictions baseball teams experience various patterns and react to factors in a repetitive manner, this ultimately affects their in-game performance and increases probability of wins.

# %% [markdown]
# # Software & Hardware Requirements:-
#
# We have used Python and Jupyter Notebook to compute the majority of this case study.
# Packages and libraries used in this project are:-
#
#     1- Pandas (data analysis)
#
#     2- Numpy (matrix computation)
#
#     3- Matplotlib.pyplot (Visualization)
#
#     4- Seaborn (visualization)
#
#     5- Scikit-Learn (Machine Learning)
#
#     6- Scipy (Z-score)
#
#     7- Joblib (saving final model)
#
#     8- Warnings (filter warnings) & etc.
#
# Microsoft Excel ( for calculations and Data Handling)
#
# Processor used:- Intel I3
#
# O/s used: 64bit Windows 10
#
# RAM:4GB

# %% [markdown]
# # Dataset Information:-
#
# Dataset provided by client in *.csv format.
#
# Our dataset consists of Major League Baseball season statistics from year 2014, resulting in a total of 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# The Input and Output features ara as:-
#
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors.
#
# Output: Number of predicted wins (W).

# %% [markdown]
# # Aim of this Project:-
#
# In this project, we will test out several machine learning models to predict the number of wins for a given team in the 2015 season based on several different indicators of success.

# %% [markdown]
# # Steps used in this project:-
#
# 1- Define the Problem
#
# 2- Data Gathering
#
# 3- Data Cleaning
#
# 4- Data Exploration and Visualization
#
# 5- Train the algorithm
#
# 6- Evaluate our model using evaluation metrics & etc.

# %% [markdown]
# # Task
# This Project is a Regression problem as output variable is continuous type of data in nature.

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#Head of our Dataset
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#Tail of our Dataset
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#shape of our Dataset
print("Shape of our dataset is ",df.shape)
print("Column count in our dataset is",df.shape[1])
print("Row count in our dataset is ",df.shape[0])
# Out:
# Shape of our dataset is  (30, 17)
# Column count in our dataset is 17
# Row count in our dataset is  30

# %%
#Let's check type of data in our Dataset
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#Checking null values in Dataset
print("Empty cells in Dataset is ",df.isna().values.any())
print("\nColumnwise Empty cell analysis\n")
print(df.isna().sum())
print("\nPlease see the detail below:-")
df.isna()
# Out:
# Empty cells in Dataset is  False
#
# Columnwise Empty cell analysis
#
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64
#
# Please see the detail below:-
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# ...

# %%
#Let's check our columns in detail
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#Concise Summary of our DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Let's check unique values in each column to exolre dataset more deeply
print("Column-wise Unique values are as:-")
for column in df.columns.values:
    print("\n Unique values in ",column," column is " ,df[column].nunique())
# Out:
# Column-wise Unique values are as:-
#
#  Unique values in  W  column is  24
#
#  Unique values in  R  column is  28
#
#  Unique values in  AB  column is  29
#
#  Unique values in  H  column is  29
#
#  Unique values in  2B  column is  22
#
#  Unique values in  3B  column is  23
#
#  Unique values in  HR  column is  27
#
#  Unique values in  BB  column is  29
#
#  Unique values in  SO  column is  29
#
#  Unique values in  SB  column is  27
#
#  Unique values in  RA  column is  30
#
#  Unique values in  ER  column is  30
#
#  Unique values in  ERA  column is  30
#
#  Unique values in  CG  column is  9
#
#  Unique values in  SHO  column is  12
#
#  Unique values in  SV  column is  20
#
#  Unique values in  E  column is  21

# %%
#checking size of dataFrame
df.size
# Out:
# 510

# %% [markdown]
# # SUMMARY STATISTICS

# %%
#Lets describe the dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#checking Transpose of Statistical summary to get better understanding:-
df.describe().transpose()
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %% [markdown]
# Observation on basis of Summary Statistics:-
#
# The Mean is more than median(50th Percentile) in 7 columns and median is more than mean in 9 columns and for sb column mean & median is same.

# %% [markdown]
# # Exploring Data Variable

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %%
#Lets check the count of values of predicted wins (W) 
sns.countplot(x="W",data=df)
plt.show()

# %% [markdown]
# Observations:-
#
# 1- Number of predicted wins (W) has most values concentrated in the categories of 68,74,76,81,83.
#
# 2- In remaining categories, few observations are present and mostly are same.

# %% [markdown]
# # Data Visualizations

# %%
#To check missing values using Seaborn Heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:-
#
# 1- Dataset has no missing values.

# %% [markdown]
# # Correlation Matrix

# %%
#Let's check correlation in our Dataset
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#checking correlation using Heatmap
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
#Heatmap with annotations & color_palette
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
# 1- Dark shades are highly correlated.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:-
#
# 1- Output feature (W) is highly correlated with SV.
#
# 2- Output feature (W) is negatively correlated with features RA,ER,ERA.
#
# 3- Earned Runs(ER) & Earned Run Average (ERA) features are very highly correlated.

# %% [markdown]
# # Plotting Outliers

# %% [markdown]
# Univariate Analysis

# %%
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(16,12))
# Out:
# W         AxesSubplot(0.125,0.772143;0.110714x0.107857)
# R      AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# AB     AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# H      AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# 2B     AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# 3B     AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# HR        AxesSubplot(0.125,0.642714;0.110714x0.107857)
# BB     AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# SO     AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# SB     AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# RA     AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# ER     AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# ERA       AxesSubplot(0.125,0.513286;0.110714x0.107857)
# CG     AxesSubplot(0.257857,0.513286;0.110714x0.107857)
# SHO    AxesSubplot(0.390714,0.513286;0.110714x0.107857)
# SV     AxesSubplot(0.523571,0.513286;0.110714x0.107857)
# E      AxesSubplot(0.656429,0.513286;0.110714x0.107857)
# ...

# %% [markdown]
# Variables in this project are numeric in nature so we have checked box plot of individual to get a much clearer idea of the distribution of attributes.In above plots outliers are present in R,ERA,SHO,SV & E columns. In ERA,SHO,SV columns data is close to whisker as compared to R & E.

# %%
#checking boxplots column wise
for i in df.columns:
    plt.subplots()
    sns.boxplot(df[i])

# %% [markdown]
# Boxplot of R, ERA, SHO & SV columns shows minimal outliers however column E have maximum outliers present.

# %% [markdown]
# Now We are creating histogram of each input variable to get an broader idea of the distribution.

# %%
# histogram of individual feature
df.hist(figsize=(18,18),grid=True)
# Out:
# array([[<AxesSubplot:title={'center':'W'}>,
#         <AxesSubplot:title={'center':'R'}>,
#         <AxesSubplot:title={'center':'AB'}>,
#         <AxesSubplot:title={'center':'H'}>],
#        [<AxesSubplot:title={'center':'2B'}>,
#         <AxesSubplot:title={'center':'3B'}>,
#         <AxesSubplot:title={'center':'HR'}>,
#         <AxesSubplot:title={'center':'BB'}>],
#        [<AxesSubplot:title={'center':'SO'}>,
#         <AxesSubplot:title={'center':'SB'}>,
#         <AxesSubplot:title={'center':'RA'}>,
#         <AxesSubplot:title={'center':'ER'}>],
#        [<AxesSubplot:title={'center':'ERA'}>,
#         <AxesSubplot:title={'center':'CG'}>,
#         <AxesSubplot:title={'center':'SHO'}>,
#         <AxesSubplot:title={'center':'SV'}>],
#        [<AxesSubplot:title={'center':'E'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Histograms are a handy way to identify outliers. Presence of unusual values in above histograms & also distribution is not normal in some columns and these things denote the possibility of potential outliers.

# %% [markdown]
# To check Distribution of Skewness

# %%
#Distplot for individual columns
for i in df.columns:
    plt.subplots()
    sns.distplot(df[i],label = i)

# %% [markdown]
# Distribution of Data in columns E, CG, H & R is not normal .
# Except these columns, some are distributed normally and others have very minimal deviation.

# %% [markdown]
# Bivariate Analysis

# %%
#Scatter Plots between output & Input variables
out_var=df['W']
input_var=df.drop(['W'],axis=1)
for i in input_var.columns:
    plt.subplots()
    sns.scatterplot(out_var,input_var[i])

# %% [markdown]
# From above scatter plot, we can look at the interaction between the variables and some variables are negatively related to each other and some plots are showing negative correlationship.

# %%
#Bar Plots between output & Input variables
for i in input_var.columns:
    plt.subplots()
    sns.barplot(out_var,input_var[i])

# %%
#checking highly correlated values with Output variable w
abs(df.corr().loc['W'].drop('W').sort_values()).plot(marker='o',markerfacecolor='red',markersize=12)
plt.show()

# %%
#Jointplot to check relation between output variable & Earned Run Average
sns.jointplot(x='W',y='ERA',data=df,kind='kde')
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
#Scatter plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(18,18),grid=True)
plt.show()

# %% [markdown]
# Using multivariate analysis we can look at the interactions between the variables.Scatterplots of all pair of attributes helps us to spot structured relationship between input variables.Diagonal grouping of some pairs of attributes suggests a high correlation and a predictable relationship.

# %% [markdown]
# # Data Visualizations

# %%
#Let's check impact of Runs on Wins
df.groupby('R')['W'].mean()
# Out:
# R
# 573     67.0
# 613     71.0
# 622     76.0
# 626     63.0
# 640     64.0
# 644     80.0
# 647    100.0
# 650     74.0
# 655     68.0
# 656     76.0
# 661     85.0
# 667     92.0
# 669     81.0
# 683     90.0
# 689     85.5
# 694     68.0
# 696     83.5
# 697     98.0
# 703     83.0
# 713     81.0
# 720     79.0
# 724     95.0
# 729     86.0
# 737     68.0
# 748     78.0
# 751     88.0
# 764     87.0
# 891     93.0
# Name: W, dtype: float64

# %%
#Let's check impact of Runs on Wins using barplot
sns.barplot(x = "R" , y = "W" ,data=df )
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# Observation:
#
# At Runs 647 win prediction is 100.

# %%
#Let's check impact of Earned Runs on Wins
am=df.groupby('ER').mean()
plt.figure(figsize=(13,9))
am['W'].plot()
plt.title('W')
# Out:
# Text(0.5, 1.0, 'W')

# %%
#Let's check impact of Earned Runs on Wins
sns.barplot(x = "ER" , y = "W" ,data=df )
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
df.groupby('ER')['W'].mean()
# Out:
# ER
# 478    100
# 532     98
# 546     97
# 553     92
# 557     90
# 572     86
# 577     83
# 584     81
# 597     84
# 601     95
# 604     80
# 609     93
# 630     85
# 638     71
# 643     76
# 646     81
# 652     87
# 653     83
# 655     74
# 659     79
# 664     68
# 677     76
# 680     88
# 682     68
# 694     78
# 698     67
# 700     64
# 746     74
# 749     63
# 799     68
# Name: W, dtype: int64

# %% [markdown]
# Observation:
#
# On basis of above plots and calculations, win prediction is 100 at 478 ER.

# %%
#Let's check impact of Errors on Wins
am=df.groupby('E').mean()
plt.figure(figsize=(13,9))
am['W'].plot()
plt.title('W')
# Out:
# Text(0.5, 1.0, 'W')

# %%
sns.barplot(x = "E" , y = "W" ,data=df )
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
df.groupby('E')['W'].mean()
# Out:
# E
# 75      92.000000
# 77      76.000000
# 78      84.000000
# 79      81.000000
# 85      86.000000
# 86      78.666667
# 88      92.666667
# 90      71.333333
# 92      74.000000
# 93      86.000000
# 94      76.000000
# 95      74.000000
# 96     100.000000
# 97      78.000000
# 101     76.000000
# 111     97.000000
# 116     68.000000
# 117     63.000000
# 119     88.000000
# 122     98.000000
# 126     68.000000
# Name: W, dtype: float64

# %%
#Skewness in dataset
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Columns R,H,CG,SV and E have presence of skewness and R have high skewness.

# %% [markdown]
# # Removing Outliers

# %%
#Lets remove the outliers if present using z scores
from scipy.stats import zscore
zs=np.abs(zscore(df))
print(zs.shape)
# Out:
# (30, 17)

# %%
#checking which data have zscore is more than 3
print(np.where(zs>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#Dropping Outliers
df1=df.loc[(abs(zs)<3).all(axis=1)]
print(df1.shape)
# Out:
# (29, 17)

# %% [markdown]
# So, as per above shapes: 30-29=1 so 1 outlier is removed and data loss is nearly 3%.

# %%
#Skewness in dataset after removing outliers
df1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
#lets chcek countplot as outliers have been removed
sns.countplot(x="W",data=df1)
plt.show()

# %%
#Lets divide dataset into input and output
x=df1.drop('W',axis=1)
x.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
print(x.shape)
# Out:
# (29, 16)

# %%
y=df1["W"]
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %%
print(y.shape)
# Out:
# (29,)

# %% [markdown]
# # Skewness

# %%
#Lets chcek the skewness of the input dataset
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
#Let's check Number of features having skewness more than 0.55
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 4

# %%
#Lets treat above skewness using cube root transformation
for index in x.skew().index:
    if x.skew().loc[index] >0.55:
        x[index]=np.cbrt(x[index])

# %%
#lets again check the skewness
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.753696
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -1.013981
# SHO    0.526943
# SV     0.280963
# E      0.671748
# dtype: float64

# %%
#Let's again check Number of features having skewness more than 0.55
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 2

# %%
#Lets treat above skewness using log transformation
for index in x.skew().index:
    if x.skew().loc[index] >0.55:
        x[index]=np.log1p(x[index])

# %%
#lets again check the skewness
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.739679
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -1.013981
# SHO    0.526943
# SV     0.280963
# E      0.599361
# dtype: float64

# %%
#Let's again check Number of features having skewness more than 0.55
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 2

# %% [markdown]
# # Preprocessing

# %%
#Lets do the preprocessing to bring features to common scale
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x1=ss.fit_transform(x)
x1=pd.DataFrame(x1,columns=x.columns)
x1.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.724122  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949553  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.089181  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.348077 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.031585  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.094672 -0.813262
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.094672  0.159299
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  1.615608 -0.326982
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.063794 -0.570122
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.063794  0.159299
#
#          SV         E
# 0  1.586882 -0.437724
# 1  0.270050 -0.599200
# 2 -0.684238 -1.193538
# ...

# %%
x1.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # Evaluate Some Algorithms (Regression)
# Our Target variable Win is continuous in nature so we will evaluate different regression algorithms to make our model.

# %%
#Let's check coefficient of determination(r2_score) to find the proportion of the variance in the 
#dependent variable that is predictable from the independent variable.
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split,cross_val_score
def maximumr2_score(rgn,x1,y):
    maximum_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=r_state,test_size=0.20)
        rgn.fit(x_train,y_train)
        pred=rgn.predict(x_test)
        r2_scr=r2_score(y_test,pred)
        if r2_scr>maximum_r_score:
            maximum_r_score=r2_scr
            final_r_state=r_state
    print('Maximum r2 score for final_r_state',final_r_state,'is',maximum_r_score)
    return final_r_state

# %%
# creating lists to store performance score
Rscore=[]
Cvscore=[]

# %% [markdown]
# # Linear Regression

# %%
#For Linear Regression
from sklearn.linear_model import LinearRegression
lg=LinearRegression()
r_state=maximumr2_score(lg,x1,y)
print('Mean r2 score for linear Regression is:',cross_val_score(lg,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for linear Regression is',cross_val_score(lg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 73 is 0.8601132105424296
# Mean r2 score for linear Regression is: -0.08782639430097128
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for linear Regression is 0.5124331475690808

# %%
#Cross Validation for Linear Regression
from sklearn import linear_model
cross_val_score(linear_model.LinearRegression(),x1,y,cv=5,scoring="r2")
# Out:
# array([ 0.49017855, -0.44933117,  0.58307498, -0.48508459, -0.57796974])

# %%
Rscore.append(0.8601132105424296)

# %% [markdown]
# # k-nearest neighbors

# %%
#Let's try to do Regression based on k-nearest neighbors.
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,27)}
knreg=KNeighborsRegressor()

# %% [markdown]
# # GridSearchCV

# %%
#using gridsearch CV to find the best parameters to use in k-nearest neighbors regression. 
from sklearn.model_selection import GridSearchCV
gridknr=GridSearchCV(knreg,neighbors,cv=10)
gridknr.fit(x1,y)
gridknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
#r2 scores for k-nearest neighbors regression.
knreg=KNeighborsRegressor(n_neighbors=5)
r_state=maximumr2_score(knreg,x1,y)
print('Mean r2 score for KNN Regression is:',cross_val_score(knreg,x1,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for KNN Regression is:',cross_val_score(knreg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.7756779339156855
# Mean r2 score for KNN Regression is: 0.01565154146494303
# standard deviation in r2 score for KNN Regression is: 0.8517897267473894

# %%
#Cross Validation for KNeighborsRegressor
cross_val_score(KNeighborsRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([ 0.09986364, -1.62526316,  0.49079046,  0.31416393,  0.79870283])

# %%
Rscore.append(0.7756779339156855)

# %% [markdown]
# # Lasso regression

# %%
#Using Lasso regression for a more accurate prediction.
from sklearn.linear_model import Lasso
lasso_reg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}

# %% [markdown]
# # GridSearch CV

# %%
gsc=GridSearchCV(lasso_reg,parameters,cv=10)
gsc.fit(x1,y)
gsc.best_params_
# Out:
# {'alpha': 1}

# %%
#As we used lasso Regression so Let's check Max & mean r2score
lasso_reg=Lasso(alpha=1)
r_state=maximumr2_score(lasso_reg,x1,y)
print('Mean r2 score for Lasso Regression is',cross_val_score(lasso_reg,x1,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for Lasso Regrssion is',cross_val_score(lasso_reg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.9578039237447185
# Mean r2 score for Lasso Regression is 0.46617816350435304
# standard deviation in r2 score for Lasso Regrssion is 0.6468548667580438

# %%
#Cross Validation for Lasso regression
cross_val_score(linear_model.Lasso(),x1,y,cv=5,scoring="r2")
# Out:
# array([ 0.73864707, -0.82374247,  0.74993932,  0.78665405,  0.87939284])

# %%
Rscore.append(0.9578039237447185)

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
r_state=maximumr2_score(dt,x1,y)
print('Mean r2 score for Decision Tree Regression is:',cross_val_score(dt,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Decision Tree Regression is',cross_val_score(dt,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 65 is 0.873821609862219
# Mean r2 score for Decision Tree Regression is: -2.142460921565603
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Decision Tree Regression is 3.9835793953001732

# %%
#Cross Validation for Decision Tree regression
cross_val_score(DecisionTreeRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([ -1.57727273, -10.61842105,   0.04809703,   0.29836066,
#         -0.51533019])

# %%
Rscore.append(0.873821609862219)

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
r_state=maximumr2_score(rf,x1,y)
print('Mean r2 score for Random Forest Regression is:',cross_val_score(rf,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Random Forest Regression is',cross_val_score(rf,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 46 is 0.8370028323435357
# Mean r2 score for Random Forest Regression is: -0.5504479973272821
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Random Forest Regression is 2.1807056939221736

# %%
Rscore.append(0.8370028323435357)

# %%
#Cross Validation for Random Forest Regression
cross_val_score(RandomForestRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([ 0.27389159, -5.40398026,  0.47915316,  0.36510328,  0.8367556 ])

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import RidgeCV
rg=RidgeCV()
r_state=maximumr2_score(rg,x1,y)
print('Mean r2 score for Ridge Regression is:',cross_val_score(rg,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Ridge Regression is',cross_val_score(rg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 46 is 0.9259526144542338
# Mean r2 score for Ridge Regression is: 0.2790384947415518
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Ridge Regression is 0.7596922528432457

# %%
Rscore.append(0.9259526144542338)

# %%
#Cross Validation for Ridge Regression
cross_val_score(linear_model.RidgeCV(),x1,y,cv=5,scoring="r2")
# Out:
# array([ 0.47646914, -1.20928224,  0.66184967,  0.54237389,  0.92378201])

# %% [markdown]
# # ADABoost Regression

# %%
#Using AdaBoost Regressor to try fitting the regression on our original dataset
from sklearn.ensemble import AdaBoostRegressor
abr=AdaBoostRegressor()

# %% [markdown]
# # HyperParameter Tuning

# %% [markdown]
# We used 6 different models and after comparing them we got 3 best models(Lasso,Ridge & Decision Tree).so now using GridSearch CV we will do Hyperparameter Tuning to find best model & parameters.

# %% [markdown]
# # HyperParameter Tuning to find best parameters Grid Search CV

# %%
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[rg,lasso_reg,DecisionTreeRegressor()]}
#using GridsearchCV to loop through predefined hyperparameters and fit our estimator on our training set.
gsc=GridSearchCV(abr,parameters,cv=5)
gsc.fit(x1,y)
gsc.best_params_
# Out:
# {'base_estimator': Lasso(alpha=1), 'learning_rate': 0.1, 'n_estimators': 10}

# %% [markdown]
# # Using best parameters in Adaboost Regression

# %%
#checking max & mean r2 scores for ADABoost Regression
abr=AdaBoostRegressor(base_estimator=lasso_reg,learning_rate=0.1,n_estimators=10)
r_state=maximumr2_score(abr,x1,y)
print('Mean r2 score for ADABoost Regression is:',cross_val_score(abr,x1,y,cv=5,scoring='r2').mean())
print('Standard Deviation in r2 score for ADABoost Regression is:',cross_val_score(abr,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.9317481953087682
# Mean r2 score for ADABoost Regression is: 0.3884383700653214
# Standard Deviation in r2 score for ADABoost Regression is: 0.7007157697004608

# %%
#Cross Validation for ADABoost regression
cross_val_score(AdaBoostRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([ 0.20138636, -5.66651748,  0.43308751,  0.35132058,  0.75159526])

# %%
Rscore.append(0.9317481953087682)

# %% [markdown]
# # Cross Validation

# %%
#Cross Validation for Linear regression
cv1=(cross_val_score(lg,x1,y,cv=5).mean())
print("Cross validation score is: ",cv1)
Cvscore.append(cv1)
# Out:
# Cross validation score is:  -0.08782639430097128

# %%
#Cross Validation for k-nearest neighbors regression
cv2=(cross_val_score(knreg,x1,y,cv=5).mean())
print("Cross validation score is: ",cv2)
Cvscore.append(cv2)
# Out:
# Cross validation score is:  0.01565154146494303

# %%
#Cross validation score for Lasso Regression
cv3=(cross_val_score(lasso_reg,x1,y,cv=5).mean())
print("Cross validation score is: ",cv3)
Cvscore.append(cv3)
# Out:
# Cross validation score is:  0.46617816350435304

# %%
#Cross Validation for Decision Tree regression
cv4=(cross_val_score(dt,x1,y,cv=5).mean())
print("Cross validation score is: ",cv4)
Cvscore.append(cv4)
# Out:
# Cross validation score is:  -2.2043947985459753

# %%
#Cross Validation for Random Forest regression
cv5=(cross_val_score(rf,x1,y,cv=5).mean())
print("Cross validation score is: ",cv5)
Cvscore.append(cv5)
# Out:
# Cross validation score is:  -0.5544236057044416

# %%
#Cross validation score for ridge Regression
cv6=(cross_val_score(rg,x1,y,cv=5).mean())
print("Cross validation score is: ",cv6)
Cvscore.append(cv6)
# Out:
# Cross validation score is:  0.2790384947415518

# %%
#Cross validation score for ADABoost Regression
cv7=(cross_val_score(abr,x1,y,cv=5).mean())
print("Cross validation score is: ",cv7)
Cvscore.append(cv7)
# Out:
# Cross validation score is:  0.4564100713668437

# %%
#List for models
model=['Linear Regression','k-nearest neighbors','Lasso regression','Decision Tree Regression','Random Forest Regression','Ridge Regression','ADABoost Regression']

# %%
#Combining all scores in one place to decide best performing models
model1=pd.DataFrame({})
model1['Model']=model
model1['Maximum r2 score']=Rscore
model1['Cross Validation Score']=Cvscore
model1.round(2)
# Out:
#                       Model  Maximum r2 score  Cross Validation Score
# 0         Linear Regression              0.86                   -0.09
# 1       k-nearest neighbors              0.78                    0.02
# 2          Lasso regression              0.96                    0.47
# 3  Decision Tree Regression              0.87                   -2.20
# 4  Random Forest Regression              0.84                   -0.55
# 5          Ridge Regression              0.93                    0.28
# 6       ADABoost Regression              0.93                    0.46

# %%
#Plotting bar plot of Maximum r2 scores of various models
plt.figure(figsize=(17,17))

plt.subplot(3,2,1)
sns.barplot(x = 'Maximum r2 score', y = 'Model', data = model1)
# Out:
# <AxesSubplot:xlabel='Maximum r2 score', ylabel='Model'>

# %% [markdown]
# Observations:-
#
# 1-After comparing above 7 models, these 3 models are best:-
#
# a- Lasso regression
#
# b-Ridge Regression
#
# c-ADABoost Regression
#
# 2-We already did Hyperparameter tuning to find best parameters using Grid Search CV so we will use those parameters in final model building.
#
# 3-So as per all calculations and plots and on basis of r2score,cross validation score & other parameters we are going to implement Lasso regression model in our project.

# %%
#finding final random state for best r2 score
r_state=maximumr2_score(lasso_reg,x1,y)
# Out:
# Maximum r2 score for final_r_state 82 is 0.9578039237447185

# %% [markdown]
# # Building the model with best parameter

# %%
#We are going to use Lasso regression in our Model as it gives best score 0.9578039237447185 at final random state 82.
x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=82,test_size=0.20)
lasso=Lasso(alpha=1)
lasso.fit(x_train,y_train)
y_pred=lasso.predict(x_test)
print(y_pred)
# Out:
# [64.80856519 79.83204191 77.95738805 90.24812277 72.22280418 85.54981886]

# %%
print(y_test)
# Out:
# 24    63
# 9     78
# 13    76
# 20    90
# 22    71
# 21    83
# Name: W, dtype: int64

# %%
#ScatterPlot between y_test and Predicted values
sns.scatterplot(y_test,y_pred)
plt.xlabel("y_test")
plt.ylabel("Predcited Values")
# Out:
# Text(0, 0.5, 'Predcited Values')

# %%
#Mean absolute error & Mean Squared Error
m1=mean_absolute_error(y_test,y_pred)
m2=mean_squared_error(y_test,y_pred)
print("Mean Absolute Error is: ",m1)
print("Mean Squared Error is: ",m2)
# Out:
# Mean Absolute Error is:  1.603123494789808
# Mean Squared Error is:  3.0861741327821193

# %%
# Lets find RMSE and r2 score after model fitting
print('Root Mean Square Error after model fitting is:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score after model fitting is:',r2_score(y_test,y_pred))
# Out:
# Root Mean Square Error after model fitting is: 1.756751016160833
# r2_score after model fitting is: 0.9578039237447185

# %% [markdown]
# # Evaluate Predictions

# %%
#lets make the dataframe for Predictions using Pandas
predict=pd.DataFrame(y_pred,columns=['Predicted Values'])
predict=pd.concat([predict,y_test.reset_index()['W']],axis=1)
predict.columns=['Predicted Values','Real Values']

# %%
#Comparing predicted and real values
predict.round(2)
# Out:
#    Predicted Values  Real Values
# 0             64.81           63
# 1             79.83           78
# 2             77.96           76
# 3             90.25           90
# 4             72.22           71
# 5             85.55           83

# %%
#Graph showing how close are predicted and Real Values
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(12,8))
sns.lineplot(x='Predicted Values',y='Real Values',data=predict,ax=ax,marker='o',markerfacecolor='green',markersize=11)
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Real Values')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1- Graph is linear and it shows best relation between predicted and real values.
#
# 2- Predicted and Real values are very much close to each other.
#
# 3- Lasso Regression Model is best for our Project.
#
# 4- R2 Score is best and error is minimum.

# %% [markdown]
# # Saving our model

# %%
import joblib
#saving model
joblib.dump(lasso,'Baseball Case Study.pkl')
# Out:
# ['Baseball Case Study.pkl']

# %% [markdown]
# # Loading the saved model

# %%
eval=joblib.load('Baseball Case Study.pkl')
pred=eval.predict(x_test)
from sklearn import metrics
print('Mean Absolute Error: {}'.format(metrics.mean_absolute_error(y_test, pred)))
print('Mean Squared Error: {}'.format(metrics.mean_squared_error(y_test, pred)))
print('Root Mean Squared Error: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, pred))))
# Out:
# Mean Absolute Error: 1.603123494789808
# Mean Squared Error: 3.0861741327821193
# Root Mean Squared Error: 1.756751016160833

# %%
#checking predicted values
print(pred)
# Out:
# [64.80856519 79.83204191 77.95738805 90.24812277 72.22280418 85.54981886]

# %% [markdown]
# Result is OK as per our model.

# %% [markdown]
# # ||HAPPY ENDING||
