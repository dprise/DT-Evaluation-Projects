# %% [markdown]
# # Avocado Price Prediction

# %% [markdown]
# # Overview:-

# %% [markdown]
# Avocado Introduction:
#
# The avocado (Persea americana), a tree likely originating from south-central Mexico, is classified as a member of the flowering plant family Lauraceae. The fruit of the plant, also called an avocado (or avocado pear or alligator pear), is botanically a large berry containing a single large seed. Avocado trees are partially self-pollinating, and are often propagated through grafting to maintain predictable fruit quality and quantity. Avocados are cultivated in tropical and Mediterranean climates of many countries,with Mexico as the leading producer of avocados in 2019, supplying 32% of the world total.The fruit of domestic varieties has a buttery flesh when ripe. Depending on the variety, avocados have green, brown, purplish, or black skin when ripe, and may be pear-shaped, egg-shaped, or spherical. Commercially, the fruits are picked while immature, and ripened after harvesting.
#
# Avocado Production:
#
# The United States is the second largest producer of avocados after Mexico. About 90% of avocado production in the United States takes place in California by more than 5,000 growers. The average grove size in California is about 13 acres. One avocado tree can produce from 200 to 500 avocados per year. Florida and Hawaii produce most of the remaining 10% of avocados produced in the United States.The avocado industry in Florida is estimated to produce more than $55 million annually and supports over 1,000 full-time and part-time jobs. Worldwide avocado production has dramatically increased from 4.6 billion pounds in 1994 to 6.8 billion pounds in 2004.

# %%
#Let's see an avocado image
from IPython import display
display.Image("avocado.jpg")

# %% [markdown]
# Avocado Consumption:-
#
# Avocado is a fruit consumed by people heavily in the United States. Avocado consumption in the United States has doubled over the past 10 years and is now about four times higher than consumption in the mid-1990s. Avocados have become more abundant in the U.S. due to a large increase in avocado imports. From 2012-2015, U.S. net production accounted for about 20% of U.S. consumption, compared to about 80% of U.S. consumption in the 1990s.
#
# Hass Avocado Board:
#
# The Hass Avocado Board (HAB) is an agricultural promotion group established in 2002 to promote the consumption of Hass avocados in the U.S. A 12-member board representing domestic producers and importers of Hass Avocados directs HAB’s promotion, research, and information programs under the supervision of the United States Department of Agriculture (USDA). Funding for HAB comes from Hass avocado producers and importers in the U.S.

# %% [markdown]
# # Avocado Prices:
#
# Avocado has become one of the world's trendiest foods. As the poster child of millennial healthy eating, this superfood is now a mainstay for foodies everywhere.Avocado prices have rocketed in recent years by up to 129%, with the average national price of a single Hass avocado reaching $2.10 in 2019, almost doubling in just one year.But as demand increased, supply had to keep up, and the true difficulties of yielding large-scale avocado crops began to show.Avocado orchards require an extraordinary amount of costly resources in order to flourish. There are multiple inputs that avocados require, whether it's water, fertilizer, pruning, pest control, the sunburn protection of trees. All those go into making your chances better of having a very good-quality crop.
#
# According to the most recent Department of Agriculture weekly retail price report, the average national price of a Hass avocado has 2.10 (US dollar) as compared to 1.17 (US dollar) from the July 6, 2018, report.

# %% [markdown]
# # Dataset Information:-
#
# Format: Dataset provided by client in *.csv format.
#
# Source: This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The tables in dataset represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
#
# type - conventional or organic
#
# year - the year
#
# Region - the city or region of the observation
#
# Total Volume - Total number of avocados sold
#
# 4046 - Total number of avocados with PLU 4046 sold
#
# 4225 - Total number of avocados with PLU 4225 sold
#
# 4770 - Total number of avocados with PLU 4770 sold
#
# Output/Target Vaiable: AveragePrice - the average price of a single avocado.

# %% [markdown]
# # Aim of this Project:-
#
# We wanted to find out which cities in the U.S. provide the most reasonable prices for avocados. So, our main task is to make a model that can consider the data provided and predict the Average Price. We also need to understand the market and trends better to fulfill this goal. We explored the data of prices and volumes of avocados sold in the major metropolitan areas, analyzed the costs at different cities and the correlation between the volume and prices, and built machine learning models to predict prices.
#
# Our main goal is to predict the Average Price of avocados & our target varibale is "AveragePrice" which is continuous in nature so we will use Regression algorithms to make our model.

# %% [markdown]
# # Software & Hardware Requirements:-
# We have used Python and Jupyter Notebook to compute the majority of this case study.
# Packages and libraries used in this project are:-
#
#     1- Pandas (data analysis)
#
#     2- Numpy (matrix computation)
#
#     3- Matplotlib.pyplot (Visualization)
#
#     4- Seaborn (visualization)
#
#     5- Scikit-Learn (Machine Learning)
#
#     6- Scipy (Z-score)
#
#     7- Joblib (saving final model)
#
#     8- Warnings (filter warnings) & etc.
#
# Microsoft Excel ( for calculations and Data Handling)
#
# Processor used:- Intel I3
#
# O/s used: 64bit Windows 10
#
# RAM:4GB

# %% [markdown]
# # Steps used in this project:-
#
# 1- Define the Problem
#
# 2- Data Gathering
#
# 3- Data Cleaning
#
# 4- Data Exploration and Visualization
#
# 5- Train the algorithm
#
# 6- Evaluate our model using evaluation metrics & etc.

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df=pd.read_csv('avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#Head of our Dataset
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
#Tail of our Dataset
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
#shape of our Dataset
print("Shape of our dataset is ",df.shape)
print("Column count in our dataset is",df.shape[1])
print("Row count in our dataset is ",df.shape[0])
# Out:
# Shape of our dataset is  (18249, 14)
# Column count in our dataset is 14
# Row count in our dataset is  18249

# %%
#Let's check type of data in our Dataset
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#Checking null values in Dataset
print("Empty cells in Dataset is ",df.isna().values.any())
print("\nColumnwise Empty cell analysis\n")
print(df.isna().sum())
print("\nPlease see the detail below:-")
df.isna()
# Out:
# Empty cells in Dataset is  False
#
# Columnwise Empty cell analysis
#
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64
#
# Please see the detail below:-
#        Unnamed: 0   Date  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False  False         False         False  False  False  False
# 1           False  False         False         False  False  False  False
# 2           False  False         False         False  False  False  False
# 3           False  False         False         False  False  False  False
# 4           False  False         False         False  False  False  False
# ...           ...    ...           ...           ...    ...    ...    ...
# ...

# %%
#Let's check our columns in detail
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
#Concise Summary of our DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# Observations:
#
# 1- We dont have any missing values in our dataset.
#
# 2-Column "Unnamed:0" is just a representation of the indexes so we will remove it and it will not effect on our dataset.
#
# 3- 3 Columns have non-numerical data type.
#
# 4- Datatype is object in date column so we have to change its type to date type and also need to extract month into a seperate column.

# %%
#Removing Column "Unnamed:0"
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#Dataset & shape of our Dataset after removal of Column "Unnamed:0"
print("Shape of our dataset is ",df.shape)
df.head()
# Out:
# Shape of our dataset is  (18249, 13)
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#Let's change the Date data type to date type
df['Date']=pd.to_datetime(df['Date'])

# %%
#Let's extract the day & month from the Date for better visulatization
df['Day']=pd.DatetimeIndex(df['Date']).day
df['Month']=pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Day  Month
# 0  Albany   27     12
# 1  Albany   20     12
# 2  Albany   13     12
# 3  Albany    6     12
# ...

# %%
#Let's check unique values in each column to exolre dataset more deeply
print("Column-wise Unique values are as:-")
for column in df.columns.values:
    print("\n Unique values in ",column," column is " ,df[column].nunique())
# Out:
# Column-wise Unique values are as:-
#
#  Unique values in  Date  column is  169
#
#  Unique values in  AveragePrice  column is  259
#
#  Unique values in  Total Volume  column is  18237
#
#  Unique values in  4046  column is  17702
#
#  Unique values in  4225  column is  18103
#
#  Unique values in  4770  column is  12071
#
#  Unique values in  Total Bags  column is  18097
#
#  Unique values in  Small Bags  column is  17321
#
#  Unique values in  Large Bags  column is  15082
#
#  Unique values in  XLarge Bags  column is  5588
#
#  Unique values in  type  column is  2
#
#  Unique values in  year  column is  4
#
#  Unique values in  region  column is  54
#
#  Unique values in  Day  column is  31
#
#  Unique values in  Month  column is  12

# %%
#checking value count of each day
df.Day.value_counts()
# Out:
# 4     756
# 11    756
# 18    755
# 25    755
# 8     648
# 10    648
# 19    648
# 5     648
# 22    648
# 15    648
# 24    648
# 17    648
# 26    648
# 12    648
# 1     648
# 3     648
# 27    540
# 28    540
# 7     540
# 13    540
# 21    540
# 29    540
# 20    540
# 14    540
# 6     539
# 2     432
# 31    432
# 23    432
# 9     432
# 30    432
# 16    432
# Name: Day, dtype: int64

# %%
#Let's check value count of object datatype columns
for col in df.columns:
    if df[col].dtype=="object":
        print(df[col].value_counts())
        print()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64
#
# SanFrancisco           338
# Detroit                338
# Chicago                338
# CincinnatiDayton       338
# Syracuse               338
# Southeast              338
# Plains                 338
# Charlotte              338
# NewYork                338
# RichmondNorfolk        338
# California             338
# NorthernNewEngland     338
# Philadelphia           338
# West                   338
# LosAngeles             338
# Boston                 338
# Houston                338
# LasVegas               338
# StLouis                338
# RaleighGreensboro      338
# Columbus               338
# Roanoke                338
# Sacramento             338
# Boise                  338
# Seattle                338
# Midsouth               338
# BuffaloRochester       338
# GreatLakes             338
# Albany                 338
# Pittsburgh             338
# SanDiego               338
# ...

# %%
#Exploring organic type avocados
df_organic = df[df['type'] == 'organic']
df_organic
# Out:
#             Date  AveragePrice  Total Volume     4046     4225    4770  \
# 9126  2015-12-27          1.83        989.55     8.16    88.59    0.00
# 9127  2015-12-20          1.89       1163.03    30.24   172.14    0.00
# 9128  2015-12-13          1.85        995.96    10.44   178.70    0.00
# 9129  2015-12-06          1.84       1158.42    90.29   104.18    0.00
# 9130  2015-11-29          1.94        831.69     0.00    94.73    0.00
# ...          ...           ...           ...      ...      ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %%
#Exploring conventional type avocados
df_conventional = df[df['type'] == 'conventional']
df_conventional
# Out:
#            Date  AveragePrice  Total Volume       4046       4225      4770  \
# 0    2015-12-27          1.33      64236.62    1036.74   54454.85     48.16
# 1    2015-12-20          1.35      54876.98     674.28   44638.81     58.33
# 2    2015-12-13          0.93     118220.22     794.70  109149.67    130.50
# 3    2015-12-06          1.08      78992.15    1132.00   71976.41     72.58
# 4    2015-11-29          1.28      51039.60     941.48   43838.39     75.78
# ...         ...           ...           ...        ...        ...       ...
# 9121 2018-02-04          0.76    1272039.80  531469.08  368948.26  13078.20
# 9122 2018-01-28          0.85     957086.16  479147.93  179489.19   7314.98
# 9123 2018-01-21          0.84    1020913.20  505263.29  177911.40   9468.95
# 9124 2018-01-14          0.90     950954.60  463945.73  188126.02  11227.47
# 9125 2018-01-07          0.88     880266.52  436282.38  178669.53   9467.11
#
# ...

# %% [markdown]
# # Data Visualizations

# %%
#checking organic vs conventional avocados demand using pie chart
Type=df.groupby('type')['Total Volume'].agg('sum')
values=[Type['conventional'],Type['organic']]
labels=['conventional','organic']
fig, ax = plt.subplots()
ax.pie(values, labels=labels, autopct='%1.1f%%',shadow=True)
ax.axis('equal')
ax.set_title('Avocado Demand')
plt.show()

# %% [markdown]
# Observation:
#
# 1- Conventional avocados are more in demand.
#
# 2- Organic avocados have only 2.8% demand.

# %%
#Let's check avocado's Average Price year wise
df.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.375590
# 2016    1.338640
# 2017    1.515128
# 2018    1.347531
# Name: AveragePrice, dtype: float64

# %%
#Let's check avocado's Average Price year wise using barplot
sns.barplot(x = "year" , y = "AveragePrice" ,data=df )
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# Observation:-
#
# In year 2017 avocado had reached at its maximum price.

# %%
#Let's check avocado's Average Price using Month column
am=df.groupby('Month').mean()
plt.figure(figsize=(13,9))
am['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %%
#Let's check avocado's Average Price month wise using barplot
sns.barplot(x = "Month", y = "AveragePrice" ,data=df )
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [markdown]
# Observation:-
#
# 1-Between 8th to 11th month, price of avocado is high as compared to other months.
#
# 2- In September & October month avocado price is at peak.

# %%
#Let's check avocado's Average Price using date column
ad=df.groupby('Date').mean()
plt.figure(figsize=(13,9))
ad['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %% [markdown]
# Observations:
#
# 1-Avocado was costly between November 2016 and December 2016 & between july 2017 & November 2017.
#
# 2-Maximum price was recorded in months of October & November 2017.

# %%
#Let's check avocado's Average Price distribution
sns.distplot(df['AveragePrice'],label = 'Average Price')
plt.show()
ad['AveragePrice'].mean()
# Out:
# 1.4059875399648945

# %% [markdown]
# Observation:
#
# Distplot shows average price distribution between 1.1 & 1.4.

# %%
#Let's check avocado's Average Price distribution for organic & coventional type using lineplot
plt.figure(figsize=(20,6))
sns.lineplot(x="Date", y="AveragePrice", hue='type', data=df)
plt.show()

# %%
#Let's check avocado's Average Price distribution for organic & coventional type using BarPlot
sns.barplot(x = "type" , y = "AveragePrice" ,data=df )
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# Observations on basis of barplot & lineplot:
#
# 1-Price was high between September 2017 and November 2017 for both type of avocados.
#
# 2- Organic avocados are costlier than conventional avocados.
#
# 3- Organic avocados are less in demand than coventional avocados (as per above pie chart) may be due to their high cost.

# %% [markdown]
# # Region wise Analysis

# %%
#Exploring region column to check avocado price & consumption region-wise
print("Region Column have ",df["region"].nunique()," cities. So we will check avocado price & consumption in these cities.")
print("\nThe cities are as:-\n", df["region"].unique())
# Out:
# Region Column have  54  cities. So we will check avocado price & consumption in these cities.
#
# The cities are as:-
#  ['Albany' 'Atlanta' 'BaltimoreWashington' 'Boise' 'Boston'
#  'BuffaloRochester' 'California' 'Charlotte' 'Chicago' 'CincinnatiDayton'
#  'Columbus' 'DallasFtWorth' 'Denver' 'Detroit' 'GrandRapids' 'GreatLakes'
#  'HarrisburgScranton' 'HartfordSpringfield' 'Houston' 'Indianapolis'
#  'Jacksonville' 'LasVegas' 'LosAngeles' 'Louisville' 'MiamiFtLauderdale'
#  'Midsouth' 'Nashville' 'NewOrleansMobile' 'NewYork' 'Northeast'
#  'NorthernNewEngland' 'Orlando' 'Philadelphia' 'PhoenixTucson'
#  'Pittsburgh' 'Plains' 'Portland' 'RaleighGreensboro' 'RichmondNorfolk'
#  'Roanoke' 'Sacramento' 'SanDiego' 'SanFrancisco' 'Seattle'
#  'SouthCarolina' 'SouthCentral' 'Southeast' 'Spokane' 'StLouis' 'Syracuse'
#  'Tampa' 'TotalUS' 'West' 'WestTexNewMexico']

# %%
#Let's check region wise avocado's Average Price 
plt.figure(figsize=(26,12))
sns.barplot(x='region',y='AveragePrice',data=df)
#to make it readable
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Region wise Average Price')
# Out:
# Text(0.5, 1.0, 'Region wise Average Price')

# %% [markdown]
# Observations:
#
# 1- Avocado price is high in Charlotte,HartfordSpringfield,NewYork,Philadelphia & Sacramento cities as compared to other cities.
#
# 2- Avocado price is maximum in HartfordSpringfield & SanFrancisco cities.

# %%
#Let's check region wise avocado's Consumption details
plt.figure(figsize=(26,12))
sns.barplot(x='region',y='Total Volume',data=df)
#to make it readable
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Total Volume')
plt.title('Region wise Consumption')
# Out:
# Text(0.5, 1.0, 'Region wise Consumption')

# %% [markdown]
# Observations:
#
# 1- Avocado consumption is high in California,GreatLakes,LosAngeles,Midsouth,Northeast,SouthCentral,Southeast & West cities.
#
# 2- Maximum amount of avocado consumed in California,SouthCentral & West cities.

# %%
#Let's check year wise market record of both type of avocados
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %% [markdown]
# Observation:
#
# 1- If we would combine analysis done before then we can conclude that in year 2017 especially in month of september & october avocado price was very high in Hartford Springfield & San Francisco cities.
#
# 2- High price of avocado in these areas may be due to high demand in 2017  or due to less supply.

# %%
#Removing Column "Date" as we have same info in 3 different features day,month & year.
df.drop('Date',axis=1,inplace=True)
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Day  Month
# 0     8603.62       93.25          0.0  conventional  2015  Albany   27     12
# 1     9408.07       97.49          0.0  conventional  2015  Albany   20     12
# 2     8042.21      103.14          0.0  conventional  2015  Albany   13     12
# 3     5677.40      133.76          0.0  conventional  2015  Albany    6     12
# 4     5986.26      197.69          0.0  conventional  2015  Albany   29     11

# %%
#Shape of our Dataset after removal of Column "Date"
print("Shape of our dataset is ",df.shape)
# Out:
# Shape of our dataset is  (18249, 14)

# %%
#To check missing values using Seaborn Heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:-
#
# Dataset has no missing values.

# %% [markdown]
# # SUMMARY STATISTICS

# %%
#Lets describe the dataset
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
#checking Transpose of Statistical summary to get better understanding:-
df.describe().transpose()
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
# Day           18249.0      15.662612  8.776281e+00     1.00      8.00
# Month         18249.0       6.177215  3.534130e+00     1.00      3.00
#
#                     50%        75%          max
# ...

# %% [markdown]
# Observation on basis of Summary Statistics:-
#
# 1- Count of every columns is 18249 and there are no missing values.
#
# 2- Column XLarge Bags have presence of huge outliers.
#
# 3- The Mean is more than median(50th Percentile) in some columns & median is more than mean in some columns.
#
# 4- if we look at difference between max value and 75%, there may be outliers in some of the columns.

# %% [markdown]
# # Feature Engineering

# %%
#checking categorical type data in our dataset
for i in df.columns:
    if df[i].dtype=="object":
        print("Categorical type features in dataset: ",i)
# Out:
# Categorical type features in dataset:  type
# Categorical type features in dataset:  region

# %%
#Encoding categorical data in to numerical format for better processing using label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtype=="object":
        df[i]=le.fit_transform(df[i].astype(str))

# %%
#checking updated datatypes in our dataset
print(df.shape)
df.dtypes
# Out:
# (18249, 14)
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# Day               int64
# Month             int64
# dtype: object

# %% [markdown]
# # Correlation Matrix

# %%
#Let's check correlation in our Dataset
dfcor=df.corr()
dfcor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
#correlation of AveragePrice to year
df[['AveragePrice','year']].corr()
# Out:
#               AveragePrice      year
# AveragePrice      1.000000  0.093197
# year              0.093197  1.000000

# %%
#correlation of AveragePrice to year
df[['AveragePrice','region']].corr()
# Out:
#               AveragePrice    region
# AveragePrice      1.000000 -0.011716
# region           -0.011716  1.000000

# %% [markdown]
# Observations:
#
# 1-Average Price is highly correlated with year.
#
# 2-Average Price is least correlated with region.

# %%
#checking correlation using Heatmap
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
#Heatmap with annotations & color_palette
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:
#
# Dark shades are highly correlated.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:-
#
# 1-Features Total Volume, 4046,4225 & 4770 are positively correlated with each other.
#
# 2-All features are not correlated with Average Price column.
#
# 3-Most of features are correlated with each other.
#
# 4-Features Region & Total volume are negatively correlated with Average Price column.
#
# 5-Region is negatively correlated with year and positively correlated with Total volume,4046,4225 & 4770 columns.

# %% [markdown]
# # Plotting Outliers

# %% [markdown]
# Univariate Analysis

# %%
#Boxplot
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(16,12))
# Out:
# AveragePrice       AxesSubplot(0.125,0.772143;0.110714x0.107857)
# Total Volume    AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# 4046            AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# 4225            AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# 4770            AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# Total Bags      AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# Small Bags         AxesSubplot(0.125,0.642714;0.110714x0.107857)
# Large Bags      AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# XLarge Bags     AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# type            AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# year            AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# region          AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# Day                AxesSubplot(0.125,0.513286;0.110714x0.107857)
# Month           AxesSubplot(0.257857,0.513286;0.110714x0.107857)
# dtype: object

# %%
#checking boxplots column wise
for i in df.columns:
    plt.subplots()
    sns.boxplot(df[i])

# %% [markdown]
# Observations:
#
# 1- Many outliers are present in dataset.
#
# 2- No outlier is present in type,region,month & day features.

# %% [markdown]
# Now We are creating histogram of each input variable to get an broader idea of the distribution.

# %%
# histogram of individual feature
df.hist(figsize=(18,18),grid=True)
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>,
#         <AxesSubplot:title={'center':'4225'}>],
#        [<AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>],
#        [<AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'region'}>],
#        [<AxesSubplot:title={'center':'Day'}>,
#         <AxesSubplot:title={'center':'Month'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Observations:
#
# Presence of unusual values in above histograms & also distribution is not normal in some columns and these things denote the possibility of potential outliers.

# %% [markdown]
# To check Distribution of Skewness

# %%
#Distplot for individual columns
for i in df.columns:
    plt.subplots()
    sns.distplot(df[i],label = i)

# %% [markdown]
# Observations:
#
# 1-Huge Skewness present in Total Volume,4046,4225,4770,Total Bags,Small Bags,Large Bags & XLarge Bags columns.
#
# 2- Except these columns,others have minimal deviation.

# %% [markdown]
# Bivariate Analysis

# %%
#Scatter Plots between output & Input variables
out_var=df['AveragePrice']
input_var=df.drop(['AveragePrice'],axis=1)
for i in input_var.columns:
    plt.subplots()
    sns.scatterplot(out_var,input_var[i])

# %% [markdown]
# Observations:
#
# 1-Features Day,Month,Region & year have positive relation.
#
# 2-Features Xlarge Bags,Small Bags,Total Bags,Total Volume & 4046 have negative relation.

# %%
#checking highly correlated values with Output variable AveragePrice
abs(df.corr().loc['AveragePrice'].drop('AveragePrice').sort_values()).plot(marker='o',markerfacecolor='red',markersize=12)
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
#Scatter plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(18,18),grid=True)
plt.show()

# %% [markdown]
# Observation:
#
# Using multivariate analysis we can look at the interactions between the variables.Scatterplots of all pair of attributes helps us to spot structured relationship between input variables.

# %%
#Skewness in dataset
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Day              0.014310
# Month            0.106617
# dtype: float64

# %% [markdown]
# Observation:
#
# Columns  Total Volume,4046,4225,4770,Total Bags,Small Bags,Large Bags and XLarge Bags have presence of high skewness.

# %% [markdown]
# # Removing Outliers

# %%
#Lets remove the outliers using z scores
from scipy.stats import zscore
zs=np.abs(zscore(df))
print(zs.shape)
# Out:
# (18249, 14)

# %%
#checking which data have zscore is more than 3
print(np.where(zs>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
#Dropping Outliers
df1=df.loc[(abs(zs)<3).all(axis=1)]
print(df1.shape)
# Out:
# (17651, 14)

# %% [markdown]
# Observation:
#
# So, as per above shapes: 18249-17651=598 so 598 outliers are removed and data loss is nearly 3%.

# %%
#Skewness in dataset after removing outliers
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Day             0.011778
# Month           0.107408
# dtype: float64

# %%
#lets chcek countplot as outliers have been removed
sns.countplot(x='AveragePrice',data=df1)
plt.show()

# %%
#Lets divide dataset into input and output
x=df1.drop('AveragePrice',axis=1)
x.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags  type  year  region  Day  Month
# 0       93.25          0.0     0  2015       0   27     12
# 1       97.49          0.0     0  2015       0   20     12
# 2      103.14          0.0     0  2015       0   13     12
# 3      133.76          0.0     0  2015       0    6     12
# 4      197.69          0.0     0  2015       0   29     11

# %%
print(x.shape)
# Out:
# (17651, 13)

# %%
#Output feature
y=df1['AveragePrice']
y.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
print(y.shape)
# Out:
# (17651,)

# %%
#Lets chcek the skewness of the input dataset
x.skew()
# Out:
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Day             0.011778
# Month           0.107408
# dtype: float64

# %%
#Let's check Number of features having skewness more than 0.55
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 8

# %%
#Lets treat above skewness using cube root transformation
for index in x.skew().index:
    if x.skew().loc[index] >0.55:
        x[index]=np.cbrt(x[index])

# %%
#lets again check the skewness
x.skew()
# Out:
# Total Volume    1.240435
# 4046            1.555876
# 4225            1.277025
# 4770            1.635614
# Total Bags      1.231831
# Small Bags      1.246033
# Large Bags      1.276213
# XLarge Bags     2.277028
# type           -0.037741
# year            0.229976
# region          0.012798
# Day             0.011778
# Month           0.107408
# dtype: float64

# %%
#Let's again check Number of features having skewness more than 0.55
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 8

# %%
#Lets treat above skewness using log transformation
for index in x.skew().index:
    if x.skew().loc[index] >0.55:
        x[index]=np.log1p(x[index])

# %%
#lets again check the skewness
x.skew()
# Out:
# Total Volume   -0.021655
# 4046           -0.382213
# 4225           -0.526104
# 4770           -0.058465
# Total Bags     -0.326649
# Small Bags     -0.803280
# Large Bags     -0.728136
# XLarge Bags     1.111691
# type           -0.037741
# year            0.229976
# region          0.012798
# Day             0.011778
# Month           0.107408
# dtype: float64

# %%
#Let's again check Number of features having skewness more than 0.55
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 1

# %%
#Lets do the preprocessing to bring features to common scale
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x1=ss.fit_transform(x)
x1=pd.DataFrame(x1,columns=x.columns)
x1.head()
# Out:
#    Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0     -0.071436 -0.608040  0.422643 -0.135164   -0.488946   -0.230796
# 1     -0.143976 -0.735388  0.348364 -0.097577   -0.447517   -0.194628
# 2      0.210377 -0.686953  0.683439  0.065602   -0.519437   -0.258067
# 3      0.023952 -0.581808  0.527104 -0.054093   -0.676073   -0.398315
# 4     -0.177336 -0.636723  0.341609 -0.045435   -0.647298   -0.377033
#
#    Large Bags  XLarge Bags      type      year    region       Day     Month
# 0   -0.571226    -0.646825 -1.019047 -1.210013 -1.695495  1.289309  1.644612
# 1   -0.561263    -0.646825 -1.019047 -1.210013 -1.695495  0.491652  1.644612
# 2   -0.548603    -0.646825 -1.019047 -1.210013 -1.695495 -0.306004  1.644612
# 3   -0.489651    -0.646825 -1.019047 -1.210013 -1.695495 -1.103660  1.644612
# 4   -0.399493    -0.646825 -1.019047 -1.210013 -1.695495  1.517211  1.362113

# %%
#Input feature
x1.shape
# Out:
# (17651, 13)

# %% [markdown]
# # Evaluate Some Algorithms (Regression)

# %% [markdown]
# Our Target variable Average Price is continuous so we will evaluate different regression algorithms to make our model.

# %%
#Let's check coefficient of determination(r2_score) to find the proportion of the variance in the 
#dependent variable that is predictable from the independent variable.
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split,cross_val_score
def maximumr2_score(rgn,x1,y):
    maximum_r_score =0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=r_state,test_size=0.20)
        rgn.fit(x_train,y_train)
        pred=rgn.predict(x_test)
        r2_scr=r2_score(y_test,pred)
        if r2_scr>maximum_r_score:
            maximum_r_score=r2_scr
            final_r_state=r_state
    print('Maximum r2 score for final_r_state',final_r_state,'is',maximum_r_score)
    return final_r_state

# %%
# creating lists to store performance score
Rscore=[]
Cvscore=[]
model=['Linear Regression','k-nearest neighbors','Decision Tree Regression','Random Forest Regression','Ridge Regression','Lasso regression']

# %% [markdown]
# # Linear Regression

# %%
#For Linear Regression
from sklearn.linear_model import LinearRegression
lg=LinearRegression()
r_state=maximumr2_score(lg,x1,y)
print('Mean r2 score for linear Regression is:',cross_val_score(lg,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for linear Regression is',cross_val_score(lg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.5714513059102652
# Mean r2 score for linear Regression is: 0.19769242429024478
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for linear Regression is 0.21421049393688166

# %%
#Cross Validation for Linear Regression
from sklearn import linear_model
cross_val_score(linear_model.LinearRegression(),x1,y,cv=5,scoring="r2")
# Out:
# array([-0.19465341,  0.20331369,  0.45328525,  0.23552413,  0.29099246])

# %% [markdown]
# # k-nearest neighbors

# %%
#Let's try to do Regression based on k-nearest neighbors.
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
neighbors={'n_neighbors':range(1,27)}
knreg=KNeighborsRegressor()

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# A Machine Learning model is defined as a mathematical model with a number of parameters that need to be learned from the data. By training a model with existing data, we are able to fit the model parameters. However, there is another kind of parameters, known as Hyperparameters, that cannot be directly learned from the regular training process. They are usually fixed before the actual training process begins. These parameters express important properties of the model such as its complexity or how fast it should learn.
#
# Models can have many hyperparameters and finding the best combination of parameters can be treated as a search problem. Two best strategies for Hyperparameter tuning are:
#
# 1- GridSearchCV 2- RandomizedSearchCV

# %% [markdown]
# # GridSearchCV

# %% [markdown]
# In GridSearchCV approach, machine learning model is evaluated for a range of hyperparameter values. This approach is called GridSearchCV, because it searches for best set of hyperparameters from a grid of hyperparameters values. Grid search requires to create two set of hyperparameters. 1-Learning Rate 2-Number of Layers
#
# Grid search trains the algorithm for all combinations by using the two set of hyperparameters (learning rate and number of layers) and measures the performance using “Cross Validation” technique. This validation technique gives assurance that our trained model got most of the patterns from the dataset.

# %%
#using gridsearch CV to find the best parameters to use in k-nearest neighbors regression. 
gridknr=GridSearchCV(knreg,neighbors,cv=10)
gridknr.fit(x1,y)
gridknr.best_params_
# Out:
# {'n_neighbors': 26}

# %%
#r2 scores for k-nearest neighbors regression.
knreg=KNeighborsRegressor(n_neighbors=26)
r_state=maximumr2_score(knreg,x1,y)
print('Mean r2 score for KNN Regression is:',cross_val_score(knreg,x1,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for KNN Regression is:',cross_val_score(knreg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.7391432525210858
# Mean r2 score for KNN Regression is: 0.18621648135203162
# standard deviation in r2 score for KNN Regression is: 0.2196022581305944

# %%
#Cross Validation for KNeighborsRegressor
cross_val_score(KNeighborsRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([-0.37278602,  0.24832193,  0.46490556,  0.06249781, -0.02010141])

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
r_state=maximumr2_score(dt,x1,y)
print('Mean r2 score for Decision Tree Regression is:',cross_val_score(dt,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Decision Tree Regression is',cross_val_score(dt,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 48 is 0.7783456675663825
# Mean r2 score for Decision Tree Regression is: -0.2619280055809533
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Decision Tree Regression is 0.4604546502236655

# %%
#Cross Validation for Decision Tree regression
cross_val_score(DecisionTreeRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([-0.90373716,  0.15083853,  0.30205806, -0.25112474, -0.35493366])

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
r_state=maximumr2_score(rf,x1,y)
print('Mean r2 score for Random Forest Regression is:',cross_val_score(rf,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Random Forest Regression is',cross_val_score(rf,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 83 is 0.8971646852376753
# Mean r2 score for Random Forest Regression is: 0.2141829509386614
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Random Forest Regression is 0.2950268673533764

# %%
#Cross Validation for Random Forest Regression
cross_val_score(RandomForestRegressor(),x1,y,cv=5,scoring="r2")
# Out:
# array([-0.22775899,  0.46774474,  0.61148743,  0.2200675 ,  0.0382302 ])

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import RidgeCV
rg=RidgeCV()
r_state=maximumr2_score(rg,x1,y)
print('Mean r2 score for Ridge Regression is:',cross_val_score(rg,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Ridge Regression is',cross_val_score(rg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.5714445207029395
# Mean r2 score for Ridge Regression is: 0.19770972575904805
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Ridge Regression is 0.21425723023091636

# %%
#Cross Validation for Ridge Regression
cross_val_score(linear_model.RidgeCV(),x1,y,cv=5,scoring="r2")
# Out:
# array([-0.19474115,  0.20331666,  0.45334907,  0.23571789,  0.29090616])

# %% [markdown]
# # Lasso regression

# %%
#Using Lasso regression for a more accurate prediction.
from sklearn.linear_model import Lasso
lasso_reg=Lasso()

# %% [markdown]
# # GridSearch CV

# %%
#using gridsearch CV to find the best parameters to use in Lasso regression. 
parameters={"alpha":[0.001,0.01,0.1,1]}
gsc=GridSearchCV(lasso_reg,parameters,cv=10)
gsc.fit(x1,y)
gsc.best_params_
# Out:
# {'alpha': 0.001}

# %%
#As we used lasso Regression so Let's check Max & mean r2score
lasso_reg=Lasso(alpha=0.001)
r_state=maximumr2_score(lasso_reg,x1,y)
print('Mean r2 score for Lasso Regression is',cross_val_score(lasso_reg,x1,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for Lasso Regrssion is',cross_val_score(lasso_reg,x1,y,cv=5,scoring='r2').std())
# Out:
# Maximum r2 score for final_r_state 82 is 0.570475339827673
# Mean r2 score for Lasso Regression is 0.19707262930693875
# standard deviation in r2 score for Lasso Regrssion is 0.21585678886361656

# %%
#Cross Validation for Lasso regression
cross_val_score(linear_model.Lasso(),x1,y,cv=5,scoring="r2")
# Out:
# array([-3.85189856, -0.63909317, -0.04763459, -0.44449249, -0.80022956])

# %% [markdown]
# # Cross Validation

# %%
#Cross Validation for Linear regression
print("Cross validation score is: ",(cross_val_score(lg,x1,y,cv=5).mean()))
Cvscore.append((cross_val_score(lg,x1,y,cv=5).mean()))
# Out:
# Cross validation score is:  0.19769242429024478

# %%
#Cross Validation for k-nearest neighbors regression
print("Cross validation score is: ",(cross_val_score(knreg,x1,y,cv=5).mean()))
Cvscore.append((cross_val_score(knreg,x1,y,cv=5).mean()))
# Out:
# Cross validation score is:  0.18621648135203162

# %%
#Cross Validation for Decision Tree regression
print("Cross validation score is: ",(cross_val_score(dt,x1,y,cv=5).mean()))
Cvscore.append((cross_val_score(dt,x1,y,cv=5).mean()))
# Out:
# Cross validation score is:  -0.24779837830077694

# %%
#Cross Validation for Random Forest regression
print("Cross validation score is: ",(cross_val_score(rf,x1,y,cv=5).mean()))
Cvscore.append((cross_val_score(rf,x1,y,cv=5).mean()))
# Out:
# Cross validation score is:  0.21965042186226108

# %%
#Cross validation score for ridge Regression
print("Cross validation score is: ",(cross_val_score(rg,x1,y,cv=5).mean()))
Cvscore.append((cross_val_score(rg,x1,y,cv=5).mean()))
# Out:
# Cross validation score is:  0.19770972575904805

# %%
#Cross validation score for Lasso Regression
print("Cross validation score is: ",(cross_val_score(lasso_reg,x1,y,cv=5).mean()))
Cvscore.append((cross_val_score(lasso_reg,x1,y,cv=5).mean()))
# Out:
# Cross validation score is:  0.19707262930693875

# %%
Rscore.append(0.5714513059102652)
Rscore.append(0.7391432525210858)
Rscore.append(0.7783456675663825)
Rscore.append(0.8971646852376753)
Rscore.append(0.5714445207029395)
Rscore.append(0.570475339827673)

# %%
#Combining all scores in one place to decide best performing models
model1=pd.DataFrame({})
model1['Model']=model
model1['Maximum r2 score']=Rscore
model1['Cross Validation Score']=Cvscore
model1.round(2)
# Out:
#                       Model  Maximum r2 score  Cross Validation Score
# 0         Linear Regression              0.57                    0.20
# 1       k-nearest neighbors              0.74                    0.19
# 2  Decision Tree Regression              0.78                   -0.23
# 3  Random Forest Regression              0.90                    0.22
# 4          Ridge Regression              0.57                    0.20
# 5          Lasso regression              0.57                    0.20

# %%
#Plotting bar plot of Maximum r2 scores of various models
plt.figure(figsize=(17,17))

plt.subplot(3,2,1)
sns.barplot(x = 'Maximum r2 score', y = 'Model', data = model1)
# Out:
# <AxesSubplot:xlabel='Maximum r2 score', ylabel='Model'>

# %% [markdown]
# Observations:-
#
# 1- After comparing above 6 models, these 2 models are best:-
#
# a- Random Forest regression
# b- k-nearest neighbors
#
# 2-Now we are going to do Hyperparameter Tuning for Random Forest regression models using RandomizedSearchCV approach for best model selection.
#
# 3-We have already used GridSearch CV to find out best parameters of k-nearest neighbors in above steps and also have calculated scores using best parameters.

# %%
#finding best random state for Random Forest regression
r_state=maximumr2_score(rf,x1,y)
# Out:
# Maximum r2 score for final_r_state 92 is 0.8980532111515473

# %% [markdown]
# # RandomizedSearchCV

# %% [markdown]
# Using Scikit-Learn’s RandomizedSearchCV method, we can define a grid of hyperparameter ranges, and randomly sample from the grid, performing K-Fold CV with each combination of values.

# %%
# Use the random grid to search for best hyperparameters
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
random_grid ={'n_estimators': [80,100],'max_features': ['sqrt', 'log2'],'max_depth': [None, 5],'min_samples_split': [4, 6],
          'min_samples_leaf': [1, 2]}
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf,param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=92, n_jobs = -1)
# Fit the random search model
rf_random.fit(x1,y)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:  2.4min finished
# {'n_estimators': 100,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': None}

# %%
#Using best parameters obtained from RandomizedSearchCV in RandomForestRegressor
rfc=RandomForestRegressor(n_estimators=100,max_depth=None,min_samples_leaf= 1, max_features= 'log2',min_samples_split=4)
print("For RandomForest Regressor R2 Score->")
r_state=maximumr2_score(rfc,x1,y)
print('Mean r2 score for Random Forest Regression is:',cross_val_score(rfc,x1,y,cv=5,scoring='r2').mean())
print("\tBest possible r2score is 1.0")
print('Standard deviation in r2 score for Random Forest Regression is',cross_val_score(rfc,x1,y,cv=5,scoring='r2').std())
# Out:
# For RandomForest Regressor R2 Score->
# Maximum r2 score for final_r_state 92 is 0.8856184143236494
# Mean r2 score for Random Forest Regression is: 0.2718656768419957
# 	Best possible r2score is 1.0
# Standard deviation in r2 score for Random Forest Regression is 0.2973310127992546

# %% [markdown]
# Observations:
#
# 1-After Comparing above 6 models and 3 models with best parameters on basis of Maximum  r2 score,cross validation score & other parameters RandomForest Regressor gives best result.
#
# 2-Even after HyperParameter Tuning RandomForest Regressor gives best results.
#
# 3-So as per all calculations and plots we are going to implement RandomForest Regressor model in our project.

# %% [markdown]
# # Building the model with best parameter

# %%
#We are going to use RandomForest Regressor in our Model as it gives best scores at final random state 92.
x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=92,test_size=0.20)
rfr=RandomForestRegressor(n_estimators=100,max_depth=None,min_samples_leaf= 1, max_features= 'log2',min_samples_split=4)
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
print(y_pred)
# Out:
# [0.82219214 1.30308646 0.95001    ... 1.23041905 1.0812     1.55292321]

# %%
print(y_test)
# Out:
# 5442     0.75
# 14418    1.28
# 6605     0.72
# 11263    1.85
# 5615     0.76
#          ...
# 12967    1.37
# 5406     1.36
# 17817    1.31
# 8606     1.03
# 10463    1.53
# Name: AveragePrice, Length: 3531, dtype: float64

# %%
#ScatterPlot between y_test and Predicted values
sns.scatterplot(y_test,y_pred)
plt.xlabel("y_test")
plt.ylabel("Predcited Values")
# Out:
# Text(0, 0.5, 'Predcited Values')

# %%
#Mean absolute error & Mean Squared Error for final model
m1=mean_absolute_error(y_test,y_pred)
m2=mean_squared_error(y_test,y_pred)
print("Mean Absolute Error is: ",m1)
print("Mean Squared Error is: ",m2)
# Out:
# Mean Absolute Error is:  0.09333817330557985
# Mean Squared Error is:  0.016607201273174034

# %%
# Lets find RMSE and r2 score after model fitting
print('Root Mean Square Error after model fitting is:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score after model fitting is:',r2_score(y_test,y_pred))
# Out:
# Root Mean Square Error after model fitting is: 0.12886893059684337
# r2_score after model fitting is: 0.8860204648629163

# %% [markdown]
# # Evaluate Predictions

# %%
#lets make the dataframe for Predictions using Pandas
predict=pd.DataFrame(y_pred,columns=['Predicted Values'])
predict=pd.concat([predict,y_test.reset_index()['AveragePrice']],axis=1)
predict.columns=['Predicted Values','Real Values']
predict.round(2)
# Out:
#       Predicted Values  Real Values
# 0                 0.82         0.75
# 1                 1.30         1.28
# 2                 0.95         0.72
# 3                 1.86         1.85
# 4                 0.82         0.76
# ...                ...          ...
# 3526              1.54         1.37
# 3527              1.27         1.36
# 3528              1.23         1.31
# 3529              1.08         1.03
# 3530              1.55         1.53
#
# [3531 rows x 2 columns]

# %%
#Graph showing how close are predicted and Real Values
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(12,8))
sns.lineplot(x='Predicted Values',y='Real Values',data=predict,ax=ax,marker='o',markerfacecolor='green',markersize=11)
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Real Values')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1-Above Plot shows Predicted values are very close to real values.
#
# 2-Mean Absolute Error & Mean Squared Error are under control.
#
# 3-After Model Fitting Root Mean Square Error is very less and R2 score is high,which shows effectiveness of this model.
#
# 4-RandomForest Regressor is best selection for this project.

# %% [markdown]
# # Saving our model

# %%
import joblib
#saving model
joblib.dump(rfr,'Avocado Price Prediction.pkl')
# Out:
# ['Avocado Price Prediction.pkl']

# %% [markdown]
# # Loading the saved model

# %%
eval=joblib.load('Avocado Price Prediction.pkl')
pred=eval.predict(x_test)
from sklearn import metrics
print('Mean Absolute Error: {}'.format(metrics.mean_absolute_error(y_test, pred)))
print('Mean Squared Error: {}'.format(metrics.mean_squared_error(y_test, pred)))
print('Root Mean Squared Error: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, pred))))
# Out:
# Mean Absolute Error: 0.09333817330557985
# Mean Squared Error: 0.016607201273174034
# Root Mean Squared Error: 0.12886893059684337

# %%
#checking predicted values
print(pred)
# Out:
# [0.82219214 1.30308646 0.95001    ... 1.23041905 1.0812     1.55292321]

# %% [markdown]
# Result is OK as per our model.
#
# As we have worked on avocado prices so enjoy eating avocado.

# %% [markdown]
# # ||HAPPY EATING||
